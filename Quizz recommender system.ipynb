# %% [markdown]
# <a href="https://colab.research.google.com/github/Guylord/APHRC_DSE_Inspire_Hackathon_2024/blob/main/Quizz%20recommender%20system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
data = {
    'user_id': [1, 1, 1, 2, 2, 2, 3, 3, 3],
    'question_id': [101, 102, 103, 101, 104, 105, 102, 103, 106],
    'difficulty': [2, 3, 1, 2, 4, 2, 3, 1, 4],
    'education_level': [1, 3, 1, 2, 4, 2, 3, 1, 4],
    'correct_responses_count': [0, 1, 1, 1, 0, 1, 1, 0, 1],
    'time_taken': [30, 45, 20, 25, 60, 35, 40, 20, 50],
    'correct': [0, 1, 1, 1, 0, 1, 1, 0, 1]  # Target variable
}

df = pd.DataFrame(data)

# %%
features = df[['difficulty', 'education_level', 'correct_responses_count', 'time_taken']]
target = df['correct']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 100.00%

# %%
def recommend_question(user_features, model, all_questions_df, X_train_columns):
    user_input = pd.DataFrame([user_features])
    question_ids = all_questions_df['question_id']

    for col in X_train_columns:
        if col not in all_questions_df:
            all_questions_df[col] = 0

    all_questions_df = all_questions_df[X_train_columns]


    predictions = model.predict(all_questions_df)

    recommended_question_id = question_ids.iloc[predictions.argmax()]
    return recommended_question_id

# %%
X_train_columns = X_train.columns.tolist()

# Example of recommending a question
user_features = {
    'difficulty': 3,
    'education_level': 3,
    'correct_responses_count': 1,
    'time_taken': 40
}

recommended_question = recommend_question(user_features, model, df, X_train_columns)
print(f"Recommended Question ID: {recommended_question}")
# Out:
# Recommended Question ID: 102

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
data = {
    'question_id': [101, 102, 103, 104, 105, 106],
    'topic': ['Math', 'Science', 'History', 'Math', 'Science', 'Geography'],
    'difficulty': [2, 3, 1, 4, 2, 4],
    'required_skill_level': [2, 3, 1, 4, 2, 4],
    'user_score': [0, 1, 1, 1, 0, 1],
    'time_taken': [30, 45, 20, 25, 60, 50],
    'correct': [0, 1, 1, 0, 1, 0]  # Target variable
}

df = pd.DataFrame(data)

# %%
features = pd.get_dummies(df[['topic', 'difficulty', 'required_skill_level', 'user_score', 'time_taken']])
target = df['correct']

scaler = StandardScaler()
features = scaler.fit_transform(features)

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=20, batch_size=4, validation_split=0.2)

# Evaluate the model on the test data
y_pred_prob = model.predict(X_test).flatten()
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.3333 - loss: 0.6795 - val_accuracy: 0.0000e+00 - val_loss: 0.8215
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6667 - loss: 0.6471 - val_accuracy: 0.0000e+00 - val_loss: 0.8169
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3333 - loss: 0.7761 - val_accuracy: 0.0000e+00 - val_loss: 0.8108
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.3333 - loss: 0.6986 - val_accuracy: 0.0000e+00 - val_loss: 0.8030
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.5157 - val_accuracy: 0.0000e+00 - val_loss: 0.7984
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3333 - loss: 0.7209 - val_accuracy: 0.0000e+00 - val_loss: 0.7923
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.6161 - val_accuracy: 0.0000e+00 - val_loss: 0.7863
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.5540 - val_accuracy: 0.0000e+00 - val_loss: 0.7833
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.5048 - val_accuracy: 0.0000e+00 - val_loss: 0.7805
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6667 - loss: 0.7395 - val_accuracy: 0.0000e+00 - val_loss: 0.7753
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6667 - loss: 0.5405 - val_accuracy: 0.0000e+00 - val_loss: 0.7705
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.4543 - val_accuracy: 0.0000e+00 - val_loss: 0.7667
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.4586 - val_accuracy: 0.0000e+00 - val_loss: 0.7619
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6667 - loss: 0.4327 - val_accuracy: 0.0000e+00 - val_loss: 0.7567
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.4365 - val_accuracy: 0.0000e+00 - val_loss: 0.7516
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.3264 - val_accuracy: 0.0000e+00 - val_loss: 0.7458
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.3042 - val_accuracy: 0.0000e+00 - val_loss: 0.7411
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.2824 - val_accuracy: 0.0000e+00 - val_loss: 0.7361
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.2987 - val_accuracy: 0.0000e+00 - val_loss: 0.7319
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.2538 - val_accuracy: 0.0000e+00 - val_loss: 0.7286
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Model Accuracy: 50.00%
